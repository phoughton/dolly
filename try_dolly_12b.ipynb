# %% [markdown]
# <a href="https://colab.research.google.com/github/phoughton/dolly/blob/main/try_dolly_12b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dolly 12b: https://huggingface.co/databricks/dolly-v2-12b

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !sudo apt-get install python3-pip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   python-pip-whl python3-setuptools python3-wheel
# Suggested packages:
#   python-setuptools-doc
# The following NEW packages will be installed:
#   python-pip-whl python3-pip python3-setuptools python3-wheel
# 0 upgraded, 4 newly installed, 0 to remove and 38 not upgraded.
# Need to get 2,389 kB of archives.
# After this operation, 4,933 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.8 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-setuptools all 45.2.0-1ubuntu0.1 [330 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.8 [231 kB]
# ...

# %%
# %pip install "accelerate>=0.16.0,<1" "transformers[torch]>=4.28.1,<5" "torch>=1.13.1,<2"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 88.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 34.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 123.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 84.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 74.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 82.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
# ...

# %%
import torch
from transformers import pipeline

generate_text = pipeline(model="databricks/dolly-v2-12b", torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="auto")
# Out:
# ...
# A new version of the following files was downloaded from https://huggingface.co/databricks/dolly-v2-12b:
# - instruct_pipeline.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# ...

# %%
res = generate_text("Explain to me the difference between nuclear fission and fusion.")
print(res[0]["generated_text"])
# Out:
# Nuclear fission and fusion are both ways that the nucleus of an atom can transform into different atomic structures. In the case of nuclear fission, or disintegration, a particle within the nucleus named the neutron triggers the breakdown. The process creates several particles, or fragments, which can range in size and can be unstable, requiring further nuclear transformations to become stable. This can lead to additional fragments, and so on, creating a cascade reaction. Nuclear fusion, on the other hand, occurs when two separate nuclei interact and merge to form one larger nucleus with more mass but less energy than the original starting bodies. This process requires a neutron, or a similar partner, to trigger the reaction. Nuclear fusion produces a single, stable, and potentially useful fragment, while nuclear fission creates potentially dangerous fragments that may require further transformations to become stable.

# %% [markdown]
# Try some questions...

# %%
res = generate_text("Please provide a CSV of European Countries and their capitals. Include the UK and its capital.")
print(res[0]["generated_text"])
# Out:
# Please see below for a full list of European countries and their capitals.
# Austria, Vienna
# Belgium, Brussels
# Bosnia and Herzegovina, Sarajevo
# Bulgaria, Sofia
# Croatia, Zagreb
# Cyprus, Nicosia
# Czech Republic, Prague
# Denmark, Copenhagen
# Estonia, Tallinn
# Finland, Helsinki
# France, Paris
# Germany, Berlin
# Greece, Athens
# Hungary, Budapest
# Iceland, Reykjavik
# Italy, Rome
# Latvia, Riga
# Lithuania, Vilnius
# Macedonia, Skopje
# Malta, Valletta
# Moldova, Chisinau
#  Netherlands, Amsterdam
#  Poland, Warsaw
# Portugal, Lisbon
# Romania, Bucharest
# Russia, Moscow
# San Marino, City of San Marino
# Serbia, Belgrade
#  Slovakia, Bratislava
#  Slovenia, Ljubljana
# Spain, Madrid
# Sweden, Stockholm
# Switzerland, Bern
# Turkey, Ankara
# Ukraine, Kiev
# United Kingdom, London

# %%
res = generate_text("Open the Pod Bay doors HAL!")
print(res[0]["generated_text"])
# Out:
# Sorry, I can’t do that. I’m suffering from rather severe neck strain.

# %%
res = generate_text("create a JSON document that includes the names of some movies and their actors")
print(res[0]["generated_text"])
# Out:
# [
#   {"Title": "Star Wars", "Actors": [ "Luke Skywalker", "Han Solo", "Darth Vader" ]},
#   {"Title": "Shawshank Redemption", "Actors": [ "Frank Prison", "Bob Going ", "Tim McFeeley" ]},
#   {"Title": "12 Angry Men", "Actors": [ "Juror #3", "Juror #4", "Juror #5" ]}
# ]

# %%
res = generate_text("create a complete and correct JSON document that includes the names of some movies and their actors")
print(res[0]["generated_text"])
# Out:
# {
#     "movies": [
#         {
#             "name": "Avatar"
#             "actor": "Zhao Wei"
#         },
#         {
#             "name": "Harry Potter"
#             "actor": "Evans, Daniel"
#         },
#         {
#             "name": "The Dark Knight"
#             "actor": "Gordon, Michael"
#         }
#     ]
# }

# %%
res = generate_text("""
Explain in plain English what what would cause this python test to fail?:
@pytest.mark.parametrize("request_data, correct_status_code, score", [
        ({"starter": [3,"C"], "crib": False, "hand": [(1,"H"), (2,"H"), (3,"H"), (4,"H")] }, 200, 14),
        ({"starter": [5,"C"], "crib": False, "hand": [(5,"H"), (5,"S"), (5,"D"), (11,"C")] }, 200, 29)

])
def test_valid_data_play_setclient(client, request_data, correct_status_code, score):

    resp = client.post("/score/show", json=request_data)

    assert resp.status_code == correct_status_code
    assert json.loads(resp.data)["score"] == score
""")
print(res[0]["generated_text"])
# Out:
# Request data with invalid hand allow to exceeute the code with incorrect status code 200. The correct status code would be 400.
# The error was caused by incorrectly created hand param, with consecutive pairs of same card values.

# %%
res = generate_text("""
Black is to White, What Left is to?
""")
print(res[0]["generated_text"])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1081: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both Black and White are colours. Left is a boolean value. Black is a colour and so is White. But Left cannot be black and it is not white. Hence the answer is yes. Black is to white as left is to?

# %%
res = generate_text("""
Black is to White, What Left is to BLANK
""")
print(res[0]["generated_text"])
# Out:
# Wikipedia has thousands of pages of content that can be extremely useful when trying to understand a new concept. Below is a sampling of Left vs. Blank.
#
# Left vs. Blank
#
# Left-handed people account for approximately 15% of the global population, but they made up approximately 35% of world’s chess players.
#
# In computing, a blank space or blank is a character sequence that is interpreted as an empty character sequence, literally a “space” that has no assigned meaning. In contrast, a left blank represents a left aligned blank space.
#
# A common kitchen tool is a ladle. A spurtle is a tool used in cooking; a special ladle used for stirring boiling soup. A ladle is left-handed, while a spurtle is blank.

# %%
res = generate_text("""
Black is to White, What Left is to BLANK.
What is BLANK?
""")
print(res[0]["generated_text"])
# Out:
# BLANK is a new standard erase file format used by Microsoft for secure erasing of hard disk drives. It is described by Microsoft as "a highly efficient, highly secure hash-based file format that is resistant to data recovery".
#
# BLANK is a file header that is 38 bytes long, and contains the hashes for the preceding data, allowing complete reconstruction of the data even in the event that some of the header information is damaged or destroyed.
